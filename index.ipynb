# %% [markdown]
# # MAS112: Essential Skills for Chemists (Semester 1)
#
# Dr. Bryony Moody - Hicks G32a - <bryony.moody@sheffield.ac.uk>

# %% [markdown]
# # Introduction to the module
#
# Welcome to the webpages and learning materials for MAS112.
#
# Below are some key details about the module:
#
# * Lecture notes
# These lecture notes detail all the mathematical knowledge you need for this semester of MAS112. Please have a copy with you when you watch the lectures as I will refer to them in lectures.
#
# INSERT INFO ABOUT EXAMINABLE AND NON EXAMINABLE, STRETCH VS NONE STRETCH
#
#
# * Blackboard
# This is the online repository for all information about the module. Please check this regularly (you will also get email updates).
# * Obtaining help with the module
# Please use the Dicussion Board on Blackboard to ask questions in the first instance - I will check this regularly. You are also strongly encouraged to come along to my student drop-in hours for in-person help.
# * Homework and practice questions
# At the end of each topic, there are some exercises. We may cover a small number of these in the lectures, but the rest you should do as independent study.
# * Tutorials
# There are no formal tutorials for mathematical content of MPS112, instead each lecture will consist of spending half the time learning new contents, and half the time practicing using exercises.
# * Assessment
# INSERT ASSESSMENT INFORMATION
# * Lectures
# You are encouraged to engage in **active learning**.
#
# `````{admonition} Have a go
# :class: tip
# At these points you will be asked to complete some workings in the lecture and/or explore a model with provided interactive python code (you will need to be logged into your GMail account to use this).
